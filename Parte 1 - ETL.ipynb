# %% [markdown]
# # ETL

# %% [markdown]
# En esta instancia, se lleva a cabo la extracción de datos desde la base de datos suministrada, seguida por su transformación y preceptiva depuración. Finalmente, se procede a cargar el dataframe resultante para su ulterior utilización.

# %% [markdown]
# ## Importar librerías

# %%
import pandas as pd
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ## Extracción de los datos

# %% [markdown]
# Se extraen los datos desde el archivo proporcionado, se crea un Dataframe para procesarlo y se visualiza su estructura.

# %%
df = pd.read_excel('Datasets/BBDD_Hospitalización.xlsx')
df.head()
# Out:
#    EDAD DIABETES HOSPITALIZACIÓN ULTIMO MES   PSA BIOPSIAS PREVIAS  \
# 0  53.0       NO                         NO   4.0               NO
# 1  56.0       NO                         NO   7.7               NO
# 2  57.0       NO                         NO  29.0               SI
# 3  56.0       NO                         NO   7.0               NO
# 4  55.0       NO                         NO  29.0               SI
#
#   VOLUMEN PROSTATICO ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS  \
# 0                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 1                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 2                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 3                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 4                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
#
#    NUMERO DE MUESTRAS TOMADAS CUP ENF. CRONICA PULMONAR OBSTRUCTIVA BIOPSIA  \
# 0                        12.0  NO                                NO     NEG
# 1                        12.0  NO                                NO     NEG
# 2                        24.0  NO                                NO     NEG
# 3                        12.0  NO                                NO     NEG
# 4                        24.0  NO                                NO     NEG
#
#   NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#   FIEBRE ITU TIPO DE CULTIVO AGENTE AISLADO  \
# 0     SI  NO              NO             NO
# 1     SI  NO              NO             NO
# 2     SI  NO     HEMOCULTIVO         E.COLI
# 3     SI  NO              NO             NO
# 4     SI  NO     HEMOCULTIVO         E.COLI
#
#                   PATRON DE RESISTENCIA HOSPITALIZACION  \
# 0                                    NO              SI
# 1                                    NO              SI
# 2   AMPI R, CIPRO R, GENTA R, SULFA M R              SI
# 3                                    NO              SI
# 4                                    NO              SI
#
#    DIAS HOSPITALIZACION MQ  DIAS HOSPITALIZACIÓN UPC
# 0                      2.0                       0.0
# 1                      5.0                       0.0
# 2                      4.0                       3.0
# 3                      5.0                       0.0
# 4                      4.0                       3.0

# %% [markdown]
# ## Transformación

# %% [markdown]
# Observamos las columnas que componen el Dataframe y su tipo de dato.

# %%
# Columnas del dataframe
df.columns
# Out:
# Index(['EDAD', 'DIABETES', 'HOSPITALIZACIÓN ULTIMO MES', 'PSA',
#        'BIOPSIAS PREVIAS', 'VOLUMEN PROSTATICO',
#        'ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS', 'NUMERO DE MUESTRAS TOMADAS',
#        'CUP', 'ENF. CRONICA PULMONAR OBSTRUCTIVA', 'BIOPSIA',
#        'NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA',
#        'FIEBRE', 'ITU', 'TIPO DE CULTIVO', 'AGENTE AISLADO',
#        'PATRON DE RESISTENCIA', 'HOSPITALIZACION', 'DIAS HOSPITALIZACION MQ',
#        'DIAS HOSPITALIZACIÓN UPC'],
#       dtype='object')

# %%
# Filtramos, eliminamos filas duplicadas y reseteamos el índice
df[df.duplicated(keep=False)]
df = df.drop_duplicates(subset=df.columns, keep='first')
df = df.reset_index(drop=True)

# %%
# Observamos nulos y tipo de datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 461 entries, 0 to 460
# Data columns (total 20 columns):
#  #   Column                                                                     Non-Null Count  Dtype
# ---  ------                                                                     --------------  -----
#  0   EDAD                                                                       460 non-null    float64
#  1   DIABETES                                                                   460 non-null    object
#  2   HOSPITALIZACIÓN ULTIMO MES                                                 460 non-null    object
#  3   PSA                                                                        456 non-null    float64
#  4   BIOPSIAS PREVIAS                                                           458 non-null    object
#  5   VOLUMEN PROSTATICO                                                         459 non-null    object
#  6   ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS                                    460 non-null    object
#  7   NUMERO DE MUESTRAS TOMADAS                                                 460 non-null    float64
#  8   CUP                                                                        459 non-null    object
#  9   ENF. CRONICA PULMONAR OBSTRUCTIVA                                          458 non-null    object
#  10  BIOPSIA                                                                    460 non-null    object
#  11  NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA  460 non-null    object
#  12  FIEBRE                                                                     460 non-null    object
#  13  ITU                                                                        460 non-null    object
#  14  TIPO DE CULTIVO                                                            460 non-null    object
#  15  AGENTE AISLADO                                                             443 non-null    object
#  16  PATRON DE RESISTENCIA                                                      460 non-null    object
#  17  HOSPITALIZACION                                                            457 non-null    object
#  18  DIAS HOSPITALIZACION MQ                                                    460 non-null    float64
#  19  DIAS HOSPITALIZACIÓN UPC                                                   460 non-null    float64
# dtypes: float64(5), object(15)
# memory usage: 72.2+ KB

# %% [markdown]
# Verificamos el tipo de dato contenido en cada columna del dataframe.

# %%
def verificar_datos(df):
    mi_dict = {"nombre_campo": [], "tipo_datos": [], "no_nulos_%": [], "nulos_%": [], "nulos": []}

    for columna in df.columns:
        porcentaje_no_nulos = (df[columna].count() / len(df)) * 100
        mi_dict["nombre_campo"].append(columna)
        mi_dict["tipo_datos"].append(df[columna].apply(type).unique())
        mi_dict["no_nulos_%"].append(round(porcentaje_no_nulos, 2))
        mi_dict["nulos_%"].append(round(100-porcentaje_no_nulos, 2))
        mi_dict["nulos"].append(df[columna].isnull().sum())

    df_info = pd.DataFrame(mi_dict)
        
    return df_info

verificar_datos(df)
# Out:
#                                          nombre_campo  \
# 0                                                EDAD
# 1                                            DIABETES
# 2                          HOSPITALIZACIÓN ULTIMO MES
# 3                                                 PSA
# 4                                    BIOPSIAS PREVIAS
# 5                                  VOLUMEN PROSTATICO
# 6             ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS
# 7                          NUMERO DE MUESTRAS TOMADAS
# 8                                                 CUP
# 9                   ENF. CRONICA PULMONAR OBSTRUCTIVA
# 10                                            BIOPSIA
# 11  NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA...
# 12                                             FIEBRE
# 13                                                ITU
# 14                                    TIPO DE CULTIVO
# 15                                     AGENTE AISLADO
# 16                              PATRON DE RESISTENCIA
# 17                                    HOSPITALIZACION
# 18                            DIAS HOSPITALIZACION MQ
# 19                           DIAS HOSPITALIZACIÓN UPC
#
#                                          tipo_datos  no_nulos_%  nulos_%  \
# 0                                 [<class 'float'>]       99.78     0.22
# 1                  [<class 'str'>, <class 'float'>]       99.78     0.22
# 2                  [<class 'str'>, <class 'float'>]       99.78     0.22
# 3                                 [<class 'float'>]       98.92     1.08
# 4                  [<class 'str'>, <class 'float'>]       99.35     0.65
# 5                  [<class 'str'>, <class 'float'>]       99.57     0.43
# 6                  [<class 'str'>, <class 'float'>]       99.78     0.22
# 7                                 [<class 'float'>]       99.78     0.22
# 8                  [<class 'str'>, <class 'float'>]       99.57     0.43
# 9                  [<class 'str'>, <class 'float'>]       99.35     0.65
# 10                 [<class 'str'>, <class 'float'>]       99.78     0.22
# 11  [<class 'int'>, <class 'str'>, <class 'float'>]       99.78     0.22
# 12                 [<class 'str'>, <class 'float'>]       99.78     0.22
# 13                 [<class 'str'>, <class 'float'>]       99.78     0.22
# 14                 [<class 'str'>, <class 'float'>]       99.78     0.22
# 15                 [<class 'str'>, <class 'float'>]       96.10     3.90
# 16                 [<class 'str'>, <class 'float'>]       99.78     0.22
# 17                 [<class 'str'>, <class 'float'>]       99.13     0.87
# 18                                [<class 'float'>]       99.78     0.22
# 19                                [<class 'float'>]       99.78     0.22
#
#     nulos
# 0       1
# 1       1
# 2       1
# 3       5
# 4       3
# 5       2
# 6       1
# 7       1
# 8       2
# 9       3
# 10      1
# 11      1
# 12      1
# 13      1
# 14      1
# 15     18
# 16      1
# 17      4
# 18      1
# 19      1

# %% [markdown]
# Inicialmente, se nota que en todas las columnas hay al menos un valor ausente, destacándose la columna "AGENTE AISLADO" con 18 valores nulos.

# %%
# Filtramos filas con valores nulos
df[df.isna().any(axis=1)]
# Out:
#      EDAD DIABETES HOSPITALIZACIÓN ULTIMO MES    PSA BIOPSIAS PREVIAS  \
# 9    44.0       NO                         NO    NaN               NO
# 26   75.0       NO                         NO  25.00               NO
# 31   63.0       NO                         NO  10.80               NO
# 70   57.0       NO                         NO    NaN               NO
# 86   58.0       NO                         NO   7.80              NaN
# 93   70.0       NO                         NO   7.20               NO
# 94   74.0       NO                         NO   5.80               NO
# 97   60.0       NO                         NO    NaN               SI
# 100  65.0       NO                         NO   5.97               NO
# 103  61.0       NO                         NO   7.00               NO
# 109  56.0       NO                         NO   4.00               NO
# 110  55.0       NO                         NO  17.00               NO
# 115  62.0       NO                         NO    NaN               NO
# 120  74.0       NO                         NO   8.00               NO
# 122  69.0       NO                         NO  13.40               SI
# 123  63.0       NO                         NO  11.00               NO
# 124  63.0       NO                         NO  21.30               SI
# 132  64.0       NO                         NO  15.60               NO
# 133  71.0       NO                         NO   5.40               NO
# 140  58.0       NO                         NO  17.00               NO
# 145  66.0       NO                         NO  11.50               NO
# 150  66.0       NO                         NO   5.10               NO
# 161  68.0       NO                         NO  15.00               NO
# 164  69.0       NO                         NO   5.10               NO
# 457  69.0       NO                         NO   4.43              NaN
# 458  67.0       NO                         NO   8.00               NO
# 459  59.0       NO                         NO   9.00               SI
# 460   NaN      NaN                        NaN    NaN              NaN
#
#     VOLUMEN PROSTATICO ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS  \
# 9                   NO          FLUOROQUINOLONA_AMINOGLICOSIDO
# 26                  SI          FLUOROQUINOLONA_AMINOGLICÓSIDO
# 31                  NO          FLUOROQUINOLONA_AMINOGLICÓSIDO
# 70                  NO          FLUOROQUINOLONA_AMINOGLICOSIDO
# 86                  SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 93                  SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 94                  NO          FLUOROQUINOLONA_AMINOGLICOSIDO
# 97                  SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 100                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 103                 NO          FLUOROQUINOLONA_AMINOGLICOSIDO
# 109                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 110                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 115                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 120                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 122                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 123                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 124                 SI                                   OTROS
# 132                 SI            CEFALOSPORINA_AMINOGLUCOCIDO
# 133                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 140                 NO          FLUOROQUINOLONA_AMINOGLICOSIDO
# 145                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 150                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 161                 NO          FLUOROQUINOLONA_AMINOGLICOSIDO
# 164                 SI                           OROQUINOLONAS
# 457                NaN          FLUOROQUINOLONA_AMINOGLICOSIDO
# 458                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 459                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 460                NaN                                     NaN
#
#      NUMERO DE MUESTRAS TOMADAS  CUP ENF. CRONICA PULMONAR OBSTRUCTIVA  \
# 9                          12.0   NO                                NO
# 26                         12.0   NO                          SI, EPOC
# 31                         12.0   NO                          SI, ASMA
# 70                         18.0   NO                                NO
# 86                         12.0   NO                                NO
# 93                         12.0   NO                                NO
# 94                         12.0   NO                                NO
# 97                         16.0   NO                                NO
# 100                        20.0   NO                                NO
# 103                        12.0   NO                                NO
# 109                        12.0   NO                                NO
# 110                        12.0   NO                                NO
# 115                         6.0   NO                                NO
# 120                        12.0   NO                                NO
# 122                        12.0   NO                                NO
# 123                        12.0   NO                                NO
# 124                        24.0   NO                                NO
# 132                        12.0   NO                                NO
# 133                        12.0   NO                                NO
# 140                        12.0   NO                                NO
# 145                        12.0   NO                                NO
# 150                        12.0   NO                                NO
# 161                        12.0   NO                                NO
# 164                        12.0   NO                                NO
# 457                        20.0  NaN                                NO
# 458                        12.0   NO                               NaN
# 459                        12.0   NO                               NaN
# 460                         NaN  NaN                               NaN
#
#                        BIOPSIA  \
# 9                          NEG
# 26   ADENOCARCINOMA GLEASON 7
# 31   ADENOCARCINOMA GLEASON 7
# 70      HIPERPLASIA PROSTATICA
# 86                         NEG
# 93    ADENOCARCINOMA GLEASON 7
# 94   ADENOCARCINOMA GLEASON 7
# 97                         NEG
# 100  ADENOCARCINOMA GLEASON 7
# 103                        NEG
# 109                        NEG
# 110  ADENOCARCINOMA GLEASON 7
# 115  ADENOCARCINOMA GLEASON 8
# 120                        NEG
# 122                        NEG
# 123                        NEG
# 124                        NEG
# 132                        NEG
# 133                        NEG
# 140                        NEG
# 145                        NEG
# 150                        NEG
# 161                        NEG
# 164                        NEG
# 457                        NEG
# 458  ADENOCARCINOMA GLEASON 7
# 459                        NEG
# 460                        NaN
#
#     NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA  \
# 9                                                    2
# 26                                                  NO
# 31                                                  NO
# 70                                                  NO
# 86                                                  NO
# 93                                                  NO
# 94                                                  NO
# 97                                                  NO
# 100                                                 NO
# 103                                                 NO
# 109                                                 NO
# 110                                                 NO
# 115                                                 NO
# 120                                                 NO
# 122                                                 NO
# 123                                                 NO
# 124                                                 NO
# 132                                                 NO
# 133                                                 NO
# 140                                                 NO
# 145                                                 NO
# 150                                                 NO
# 161                                                 NO
# 164                                                 NO
# 457                                                 NO
# 458                                                 NO
# 459                                                 NO
# 460                                                NaN
#
#     FIEBRE  ITU TIPO DE CULTIVO AGENTE AISLADO PATRON DE RESISTENCIA  \
# 9       SI   NO              NO             NO                    NO
# 26      NO   NO              NO            NaN                    NO
# 31      NO   NO              NO             NO                    NO
# 70      NO   NO              NO             NO                    NO
# 86      NO   NO              NO             NO                    NO
# 93      NO   NO              NO            NaN                    NO
# 94      NO   NO              NO             NO                    NO
# 97      NO   NO              NO             NO                    NO
# 100     NO   NO              NO            NaN                    NO
# 103     NO   NO              NO             NO                    NO
# 109     NO   NO              NO            NaN                    NO
# 110     NO   NO              NO            NaN                    NO
# 115     NO   NO              NO             NO                    NO
# 120     NO   NO              NO            NaN                    NO
# 122     NO   NO              NO            NaN                    NO
# 123     NO   NO              NO            NaN                    NO
# 124     NO   NO              NO            NaN                    NO
# 132     NO   NO              NO            NaN                    NO
# 133     NO   NO              NO            NaN                    NO
# 140     NO   NO              NO            NaN                    NO
# 145     NO   NO              NO            NaN                    NO
# 150     NO   NO              NO            NaN                    NO
# 161     NO   NO              NO            NaN                    NO
# 164     NO   NO              NO            NaN                    NO
# 457     NO   NO              NO             NO                    NO
# 458     NO   NO              NO            NaN                    NO
# 459     NO   NO              NO             NO                    NO
# 460    NaN  NaN             NaN            NaN                   NaN
#
#     HOSPITALIZACION  DIAS HOSPITALIZACION MQ  DIAS HOSPITALIZACIÓN UPC
# 9                SI                      3.0                       0.0
# 26               NO                      0.0                       0.0
# 31              NaN                      0.0                       0.0
# 70               NO                      0.0                       0.0
# 86               NO                      0.0                       0.0
# 93               NO                      0.0                       0.0
# 94              NaN                      0.0                       0.0
# 97               NO                      0.0                       0.0
# 100              NO                      0.0                       0.0
# 103             NaN                      0.0                       0.0
# 109              NO                      0.0                       0.0
# 110              NO                      0.0                       0.0
# 115              NO                      0.0                       0.0
# 120              NO                      0.0                       0.0
# 122              NO                      0.0                       0.0
# 123              NO                      0.0                       0.0
# 124              NO                      0.0                       0.0
# 132              NO                      0.0                       0.0
# 133              NO                      0.0                       0.0
# 140              NO                      0.0                       0.0
# 145              NO                      0.0                       0.0
# 150              NO                      0.0                       0.0
# 161              NO                      0.0                       0.0
# 164              NO                      0.0                       0.0
# 457              NO                      0.0                       0.0
# 458              NO                      0.0                       0.0
# 459              NO                      0.0                       0.0
# 460             NaN                      NaN                       NaN

# %%
registros_nulos = len(df[df.isna().any(axis=1)])

print(f'Registros nulos: {registros_nulos}.')
# Out:
# Registros nulos: 28.

# %% [markdown]
# Borramos los registros nulos.

# %%
df = df.dropna()

# %%
# Verificamos nuevamente cantidad de nulos
verificar_datos(df)
# Out:
#                                          nombre_campo  \
# 0                                                EDAD
# 1                                            DIABETES
# 2                          HOSPITALIZACIÓN ULTIMO MES
# 3                                                 PSA
# 4                                    BIOPSIAS PREVIAS
# 5                                  VOLUMEN PROSTATICO
# 6             ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS
# 7                          NUMERO DE MUESTRAS TOMADAS
# 8                                                 CUP
# 9                   ENF. CRONICA PULMONAR OBSTRUCTIVA
# 10                                            BIOPSIA
# 11  NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA...
# 12                                             FIEBRE
# 13                                                ITU
# 14                                    TIPO DE CULTIVO
# 15                                     AGENTE AISLADO
# 16                              PATRON DE RESISTENCIA
# 17                                    HOSPITALIZACION
# 18                            DIAS HOSPITALIZACION MQ
# 19                           DIAS HOSPITALIZACIÓN UPC
#
#                         tipo_datos  no_nulos_%  nulos_%  nulos
# 0                [<class 'float'>]       100.0      0.0      0
# 1                  [<class 'str'>]       100.0      0.0      0
# 2                  [<class 'str'>]       100.0      0.0      0
# 3                [<class 'float'>]       100.0      0.0      0
# 4                  [<class 'str'>]       100.0      0.0      0
# 5                  [<class 'str'>]       100.0      0.0      0
# 6                  [<class 'str'>]       100.0      0.0      0
# 7                [<class 'float'>]       100.0      0.0      0
# 8                  [<class 'str'>]       100.0      0.0      0
# 9                  [<class 'str'>]       100.0      0.0      0
# 10                 [<class 'str'>]       100.0      0.0      0
# 11  [<class 'int'>, <class 'str'>]       100.0      0.0      0
# 12                 [<class 'str'>]       100.0      0.0      0
# 13                 [<class 'str'>]       100.0      0.0      0
# 14                 [<class 'str'>]       100.0      0.0      0
# 15                 [<class 'str'>]       100.0      0.0      0
# 16                 [<class 'str'>]       100.0      0.0      0
# 17                 [<class 'str'>]       100.0      0.0      0
# 18               [<class 'float'>]       100.0      0.0      0
# 19               [<class 'float'>]       100.0      0.0      0

# %% [markdown]
# Observamos que la columna 'NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA' tiene valores de tipo string (NO) y valores de tipo integer por lo que optamos por reemplazar los valores de tipo string por 0.

# %%
df['NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA'] = df['NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA'].replace('NO', 0)
df['NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA'].unique()
# Out:
# array([1, 2, 3, 5, 9, 0], dtype=int64)

# %% [markdown]
# Convertimos las columnas que poseen datos numéricos al tipo integer.

# %%
df['EDAD'] = df['EDAD'].astype(int)
df['NUMERO DE MUESTRAS TOMADAS'] = df['NUMERO DE MUESTRAS TOMADAS'].astype(int)
df['DIAS HOSPITALIZACION MQ'] = df['DIAS HOSPITALIZACION MQ'].astype(int)
df['DIAS HOSPITALIZACIÓN UPC'] = df['DIAS HOSPITALIZACIÓN UPC'].astype(int)

# %% [markdown]
# Renombramos columnas con faltas ortográficas y unificamos contenido que tenga errores.

# %%
df.rename(columns={'ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS': 'ANTIBIOTICO UTILIZADO EN LA PROFILAXIS'}, inplace=True)

# %%
df['ANTIBIOTICO UTILIZADO EN LA PROFILAXIS'].unique()
# Out:
# array(['FLUOROQUINOLONA_AMINOGLICOSIDO', 'CEFALOSPORINA_AMINOGLUCOCIDO',
#        'OROQUINOLONAS', 'OTROS', 'FLUOROQUINOLONA_AMINOGLICÓSIDO'],
#       dtype=object)

# %%
df['ANTIBIOTICO UTILIZADO EN LA PROFILAXIS'] = df['ANTIBIOTICO UTILIZADO EN LA PROFILAXIS'].replace('FLUOROQUINOLONA_AMINOGLICÓSIDO', 'FLUOROQUINOLONA_AMINOGLICOSIDO')

# %%
df['ANTIBIOTICO UTILIZADO EN LA PROFILAXIS'].unique()
# Out:
# array(['FLUOROQUINOLONA_AMINOGLICOSIDO', 'CEFALOSPORINA_AMINOGLUCOCIDO',
#        'OROQUINOLONAS', 'OTROS'], dtype=object)

# %%
# Observamos contenido de la columna 'ENF. CRONICA PULMONAR OBSTRUCTIVA' 
df['ENF. CRONICA PULMONAR OBSTRUCTIVA'].unique()
# Out:
# array(['NO', 'SI, EPOC', 'SI, ASMA', 'SI'], dtype=object)

# %%
# Unificamos valores renombrando
df['ENF. CRONICA PULMONAR OBSTRUCTIVA'] = df['ENF. CRONICA PULMONAR OBSTRUCTIVA'].replace('SI, EPOC', 
                                                                                          'SI')
df['ENF. CRONICA PULMONAR OBSTRUCTIVA'] = df['ENF. CRONICA PULMONAR OBSTRUCTIVA'].replace('SI, ASMA', 
                                                                                          'SI')

# %%
# Observamos contenido de la columna 'BIOPSIA' y unificamos valores renombrando
df['BIOPSIA'].unique()
# Out:
# array(['NEG', 'ADENOCARCINOMA GLEASON 6 ', 'ADENOCARCINOMA GLEASON 7 ',
#        'ADENOCARCINOMA GLEASON 6', 'ADENOCARCINOMA GLEASON 10 ',
#        'ADENOCARCINOMA GLEASON 9 ', 'ADENOCARCINOMA GLEASON 8 ',
#        'PROSTATITIS', 'ADENOCARCINOMA GLEASON 7',
#        'HIPERPLASIA PROSTATICA',
#        'CARCINOMA INDIFERENCIADO DE CELULAS CLARAS'], dtype=object)

# %%
df['BIOPSIA'] = df['BIOPSIA'].replace('ADENOCARCINOMA GLEASON 6 ',
                                      'ADENOCARCINOMA GLEASON 6')
df['BIOPSIA'] = df['BIOPSIA'].replace('ADENOCARCINOMA GLEASON 7 ',
                                      'ADENOCARCINOMA GLEASON 7')
df['BIOPSIA'] = df['BIOPSIA'].replace('ADENOCARCINOMA GLEASON 8 ',
                                      'ADENOCARCINOMA GLEASON 8')
df['BIOPSIA'] = df['BIOPSIA'].replace('ADENOCARCINOMA GLEASON 9 ',
                                      'ADENOCARCINOMA GLEASON 9')
df['BIOPSIA'] = df['BIOPSIA'].replace('ADENOCARCINOMA GLEASON 10 ',
                                      'ADENOCARCINOMA GLEASON 10')

# %%
# Observamos contenido de la columna 'PATRON DE RESISTENCIA' y unificamos valores renombrando 
df['PATRON DE RESISTENCIA'].unique()
# Out:
# array(['NO', ' AMPI R, CIPRO R, GENTA R, SULFA M R',
#        'RESISTENTE A AMPI, CIPRO Y GENTA',
#        'RESISTENTE A AMPI, SULFA, CEFADROXILO, CEFUROXIMO, CIPRO Y CEFEPIME, CEFOTAXIMA',
#        'MULTI SENSIBLE'], dtype=object)

# %%
df['PATRON DE RESISTENCIA'] = df['PATRON DE RESISTENCIA'].replace(' AMPI R, CIPRO R, GENTA R, SULFA M R', 
                                                                  'R AMPI, R GENTA, R SULFA')
df['PATRON DE RESISTENCIA'] = df['PATRON DE RESISTENCIA'].replace('RESISTENTE A AMPI, CIPRO Y GENTA', 
                                                                  'R AMPI, R CIPRO, R GENTA')
df['PATRON DE RESISTENCIA'] = df['PATRON DE RESISTENCIA'].replace('RESISTENTE A AMPI, SULFA, CEFADROXILO, CEFUROXIMO, CIPRO Y CEFEPIME, CEFOTAXIMA', 
                                                                  'R AMPI, R SULFA, R CEFADROXILO, R CEFUROXIMO, R CIPRO, R CEFEPIME, R CEFOTAXIMA')

# %%
# Se revisan nuevamente los tipos de datos y los nulos
verificar_datos(df)
# Out:
#                                          nombre_campo         tipo_datos  \
# 0                                                EDAD    [<class 'int'>]
# 1                                            DIABETES    [<class 'str'>]
# 2                          HOSPITALIZACIÓN ULTIMO MES    [<class 'str'>]
# 3                                                 PSA  [<class 'float'>]
# 4                                    BIOPSIAS PREVIAS    [<class 'str'>]
# 5                                  VOLUMEN PROSTATICO    [<class 'str'>]
# 6              ANTIBIOTICO UTILIZADO EN LA PROFILAXIS    [<class 'str'>]
# 7                          NUMERO DE MUESTRAS TOMADAS    [<class 'int'>]
# 8                                                 CUP    [<class 'str'>]
# 9                   ENF. CRONICA PULMONAR OBSTRUCTIVA    [<class 'str'>]
# 10                                            BIOPSIA    [<class 'str'>]
# 11  NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA...    [<class 'int'>]
# 12                                             FIEBRE    [<class 'str'>]
# 13                                                ITU    [<class 'str'>]
# 14                                    TIPO DE CULTIVO    [<class 'str'>]
# 15                                     AGENTE AISLADO    [<class 'str'>]
# 16                              PATRON DE RESISTENCIA    [<class 'str'>]
# 17                                    HOSPITALIZACION    [<class 'str'>]
# 18                            DIAS HOSPITALIZACION MQ    [<class 'int'>]
# 19                           DIAS HOSPITALIZACIÓN UPC    [<class 'int'>]
#
#     no_nulos_%  nulos_%  nulos
# 0        100.0      0.0      0
# 1        100.0      0.0      0
# 2        100.0      0.0      0
# 3        100.0      0.0      0
# 4        100.0      0.0      0
# 5        100.0      0.0      0
# 6        100.0      0.0      0
# 7        100.0      0.0      0
# 8        100.0      0.0      0
# 9        100.0      0.0      0
# 10       100.0      0.0      0
# 11       100.0      0.0      0
# 12       100.0      0.0      0
# 13       100.0      0.0      0
# 14       100.0      0.0      0
# 15       100.0      0.0      0
# 16       100.0      0.0      0
# 17       100.0      0.0      0
# 18       100.0      0.0      0
# 19       100.0      0.0      0

# %% [markdown]
# # Guardamos los cambios en un nuevo archivo csv

# %%
df.to_csv('Datasets/BBDD_hospitalizacion_2.csv', index=False, encoding='utf-8')
